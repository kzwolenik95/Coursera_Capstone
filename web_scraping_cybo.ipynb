# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from chromedriver_py import binary_path
import csv, random
from time import sleep

berlin_url = 'https://postal-codes.cybo.com/germany/berlin/#listcodes'
amsterdam_url = 'https://postal-codes.cybo.com/netherlands/amsterdam/#listcodes'

# %% [markdown]
# I use selenium as the page have protection from basic webscraping

# %%
driver = webdriver.Chrome(executable_path=binary_path)

# %%
driver.get(berlin_url)
berlin_page_html = driver.execute_script("return document.body.innerHTML;")
driver.get(amsterdam_url)
amsterdam_page_html = driver.execute_script("return document.body.innerHTML;")

# %%
berlin_soup = BeautifulSoup(berlin_page_html, 'html.parser')
amsterdam_soup = BeautifulSoup(amsterdam_page_html, 'html.parser')

# %% [markdown]
# First I scrape a tables with all the postal codes of the cities from the berlin_url and amsterdam_url. Then I save it to the disk to avoid scraping the pages again.

# %%
#save to csv file
with open('berlin_codes.csv', mode='w', newline='', encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file, delimiter=';')

    berlin_html_table = berlin_soup.find_all('table')[2]
    for row in berlin_html_table.find_all('tr'):
        row = [str(column.text).replace(' km²', '').replace('Area', 'Area km²').strip() for column in row.find_all(['td', 'th'])]
        csv_writer.writerow(row)

# %%
#save to csv file
with open('amsterdam_codes.csv', mode='w', newline='', encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file, delimiter=';')

    amsterdam_html_table = amsterdam_soup.find_all('table')[1]
    for row in amsterdam_html_table.find_all('tr'):
        row = [str(column.text).replace(' km²', '').replace('Area', 'Area km²').strip() for column in row.find_all(['td', 'th'])]
        csv_writer.writerow(row)

# %% [markdown]
# Then, I scrape the details URL link and I enter each link and I scape the details, saving them on the disk to avoid scraping again. This is necessary because this web traffic is very unnatural and the website protection could trigger.

# %%
url_protocol = 'https:'
berlin_html_table = berlin_soup.find_all('table')[2]
with open('berlin_details.csv', mode='w', newline='', encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file, delimiter=';')
    csv_writer.writerow(['Postal Code', 'Median Age', 'Neighborhoods', 'Latitude', 'Longitude']) # Header

    for row in berlin_html_table.find_all('tr'):
        if row.find('th'):
            continue
        postal_code = (row.find('td').text)
        details_url = url_protocol + row.find('td').find('a')['href']
        print(postal_code, details_url)

        #we need to scrape details page for each code to get necessary information
        driver.get(details_url) 
        details_soup = BeautifulSoup(driver.execute_script("return document.body.innerHTML;"), 'html.parser')
        details_html_table = details_soup.find('table')
        for row in details_html_table.find_all('tr'):
            row = [str(column.text).replace(' km²', '').replace('Area', 'Area km²').strip() for column in row.find_all(['td', 'th'])]
            if row[0] in ['Neighborhoods']:
                neighborhoods = row[1]
            elif row[0] in ['Coordinates']:
                coords = str(row[1]).replace('°', '').split(u'\xa0/\xa0')
                latitude = coords[0]
                longitude = coords[1]
            elif row[0] in ['Median Age']:
                median_age = str(row[1]).replace(' years', '')
        csv_writer.writerow([postal_code, median_age, neighborhoods, latitude, longitude])
        csv_file.flush()
        # sleep to avoid being blocked by website protection
        sleep(random.randint(5, 9))
# Out:
# 10115 https://postal-codes.cybo.com/germany/10115_berlin-berlin/
# 10117 https://postal-codes.cybo.com/germany/10117_berlin-berlin/
# 10119 https://postal-codes.cybo.com/germany/10119_berlin-berlin/
# 10178 https://postal-codes.cybo.com/germany/10178_berlin-berlin/
# 10179 https://postal-codes.cybo.com/germany/10179_berlin-berlin/
# 10243 https://postal-codes.cybo.com/germany/10243_berlin-berlin/
# 10245 https://postal-codes.cybo.com/germany/10245_berlin-berlin/
# 10247 https://postal-codes.cybo.com/germany/10247_berlin-berlin/
# 10249 https://postal-codes.cybo.com/germany/10249_berlin-berlin/
# 10315 https://postal-codes.cybo.com/germany/10315_berlin-berlin/
# 10317 https://postal-codes.cybo.com/germany/10317_berlin-berlin/
# 10318 https://postal-codes.cybo.com/germany/10318_berlin-berlin/
# 10319 https://postal-codes.cybo.com/germany/10319_berlin-berlin/
# 10365 https://postal-codes.cybo.com/germany/10365_berlin-berlin/
# 10367 https://postal-codes.cybo.com/germany/10367_berlin-berlin/
# 10369 https://postal-codes.cybo.com/germany/10369_berlin-berlin/
# 10405 https://postal-codes.cybo.com/germany/10405_berlin-berlin/
# 10407 https://postal-codes.cybo.com/germany/10407_berlin-berlin/
# 10409 https://postal-codes.cybo.com/germany/10409_berlin-berlin/
# 10435 https://postal-codes.cybo.com/germany/10435_berlin-berlin/
# 10437 https://postal-codes.cybo.com/germany/10437_berlin-berlin/
# 10439 https://postal-codes.cybo.com/germany/10439_berlin-berlin/
# 10551 https://postal-codes.cybo.com/germany/10551_berlin-berlin/
# 10553 https://postal-codes.cybo.com/germany/10553_berlin-berlin/
# 10555 https://postal-codes.cybo.com/germany/10555_berlin-berlin/
# 10557 https://postal-codes.cybo.com/germany/10557_berlin-berlin/
# 10559 https://postal-codes.cybo.com/germany/10559_berlin-berlin/
# 10585 https://postal-codes.cybo.com/germany/10585_berlin-berlin/
# 10587 https://postal-codes.cybo.com/germany/10587_berlin-berlin/
# 10589 https://postal-codes.cybo.com/germany/10589_berlin-berlin/
# 10623 https://postal-codes.cybo.com/germany/10623_berlin-berlin/
# 10625 https://postal-codes.cybo.com/germany/10625_berlin-berlin/
# 10627 https://postal-codes.cybo.com/germany/10627_berlin-berlin/
# 10629 https://postal-codes.cybo.com/germany/10629_berlin-berlin/
# 10707 https://postal-codes.cybo.com/germany/10707_berlin-berlin/
# 10709 https://postal-codes.cybo.com/germany/10709_berlin-berlin/
# 10711 https://postal-codes.cybo.com/germany/10711_berlin-berlin/
# 10713 https://postal-codes.cybo.com/germany/10713_berlin-berlin/
# 10715 https://postal-codes.cybo.com/germany/10715_berlin-berlin/
# 10717 https://postal-codes.cybo.com/germany/10717_berlin-berlin/
# 10719 https://postal-codes.cybo.com/germany/10719_berlin-berlin/
# 10777 https://postal-codes.cybo.com/germany/10777_berlin-berlin/
# 10779 https://postal-codes.cybo.com/germany/10779_berlin-berlin/
# 10781 https://postal-codes.cybo.com/germany/10781_berlin-berlin/
# 10783 https://postal-codes.cybo.com/germany/10783_berlin-berlin/
# 10785 https://postal-codes.cybo.com/germany/10785_berlin-berlin/
# 10787 https://postal-codes.cybo.com/germany/10787_berlin-berlin/
# 10789 https://postal-codes.cybo.com/germany/10789_berlin-berlin/
# 10823 https://postal-codes.cybo.com/germany/10823_berlin-berlin/
# 10825 https://postal-codes.cybo.com/germany/10825_berlin-berlin/
# 10827 https://postal-codes.cybo.com/germany/10827_berlin-berlin/
# 10829 https://postal-codes.cybo.com/germany/10829_berlin-berlin/
# 10961 https://postal-codes.cybo.com/germany/10961_berlin-berlin/
# 10963 https://postal-codes.cybo.com/germany/10963_berlin-berlin/
# 10965 https://postal-codes.cybo.com/germany/10965_berlin-berlin/
# 10967 https://postal-codes.cybo.com/germany/10967_berlin-berlin/
# 10969 https://postal-codes.cybo.com/germany/10969_berlin-berlin/
# 10997 https://postal-codes.cybo.com/germany/10997_berlin-berlin/
# 10999 https://postal-codes.cybo.com/germany/10999_berlin-berlin/
# 11011 https://postal-codes.cybo.com/germany/11011_berlin-berlin/
# 12043 https://postal-codes.cybo.com/germany/12043_berlin-berlin/
# 12045 https://postal-codes.cybo.com/germany/12045_berlin-berlin/
# 12047 https://postal-codes.cybo.com/germany/12047_berlin-berlin/
# 12049 https://postal-codes.cybo.com/germany/12049_berlin-berlin/
# 12051 https://postal-codes.cybo.com/germany/12051_berlin-berlin/
# 12053 https://postal-codes.cybo.com/germany/12053_berlin-berlin/
# 12055 https://postal-codes.cybo.com/germany/12055_berlin-berlin/
# 12057 https://postal-codes.cybo.com/germany/12057_berlin-berlin/
# 12059 https://postal-codes.cybo.com/germany/12059_berlin-berlin/
# 12099 https://postal-codes.cybo.com/germany/12099_berlin-berlin/
# 12101 https://postal-codes.cybo.com/germany/12101_berlin-berlin/
# 12103 https://postal-codes.cybo.com/germany/12103_berlin-berlin/
# 12105 https://postal-codes.cybo.com/germany/12105_berlin-berlin/
# 12107 https://postal-codes.cybo.com/germany/12107_berlin-berlin/
# 12109 https://postal-codes.cybo.com/germany/12109_berlin-berlin/
# 12157 https://postal-codes.cybo.com/germany/12157_berlin-berlin/
# 12159 https://postal-codes.cybo.com/germany/12159_berlin-berlin/
# 12161 https://postal-codes.cybo.com/germany/12161_berlin-berlin/
# 12163 https://postal-codes.cybo.com/germany/12163_berlin-berlin/
# 12165 https://postal-codes.cybo.com/germany/12165_berlin-berlin/
# 12167 https://postal-codes.cybo.com/germany/12167_berlin-berlin/
# 12169 https://postal-codes.cybo.com/germany/12169_berlin-berlin/
# 12203 https://postal-codes.cybo.com/germany/12203_berlin-berlin/
# 12205 https://postal-codes.cybo.com/germany/12205_berlin-berlin/
# 12207 https://postal-codes.cybo.com/germany/12207_berlin-berlin/
# 12209 https://postal-codes.cybo.com/germany/12209_berlin-berlin/
# 12247 https://postal-codes.cybo.com/germany/12247_berlin-berlin/
# 12249 https://postal-codes.cybo.com/germany/12249_berlin-berlin/
# 12277 https://postal-codes.cybo.com/germany/12277_berlin-berlin/
# 12279 https://postal-codes.cybo.com/germany/12279_berlin-berlin/
# 12305 https://postal-codes.cybo.com/germany/12305_berlin-berlin/
# 12307 https://postal-codes.cybo.com/germany/12307_berlin-berlin/
# 12309 https://postal-codes.cybo.com/germany/12309_berlin-berlin/
# 12347 https://postal-codes.cybo.com/germany/12347_berlin-berlin/
# 12349 https://postal-codes.cybo.com/germany/12349_berlin-berlin/
# 12351 https://postal-codes.cybo.com/germany/12351_berlin-berlin/
# 12353 https://postal-codes.cybo.com/germany/12353_berlin-berlin/
# 12355 https://postal-codes.cybo.com/germany/12355_berlin-berlin/
# 12357 https://postal-codes.cybo.com/germany/12357_berlin-berlin/
# 12359 https://postal-codes.cybo.com/germany/12359_berlin-berlin/
# 12435 https://postal-codes.cybo.com/germany/12435_berlin-berlin/
# 12437 https://postal-codes.cybo.com/germany/12437_berlin-berlin/
# 12439 https://postal-codes.cybo.com/germany/12439_berlin-berlin/
# 12459 https://postal-codes.cybo.com/germany/12459_berlin-berlin/
# 12487 https://postal-codes.cybo.com/germany/12487_berlin-berlin/
# 12489 https://postal-codes.cybo.com/germany/12489_berlin-berlin/
# 12521 https://postal-codes.cybo.com/germany/12521_berlin-berlin/
# 12524 https://postal-codes.cybo.com/germany/12524_berlin-berlin/
# 12526 https://postal-codes.cybo.com/germany/12526_berlin-berlin/
# 12527 https://postal-codes.cybo.com/germany/12527_berlin-berlin/
# 12529 https://postal-codes.cybo.com/germany/12529_berlin-berlin/
# 12555 https://postal-codes.cybo.com/germany/12555_berlin-berlin/
# 12557 https://postal-codes.cybo.com/germany/12557_berlin-berlin/
# 12559 https://postal-codes.cybo.com/germany/12559_berlin-berlin/
# 12587 https://postal-codes.cybo.com/germany/12587_berlin-berlin/
# 12589 https://postal-codes.cybo.com/germany/12589_berlin-berlin/
# 12619 https://postal-codes.cybo.com/germany/12619_berlin-berlin/
# 12621 https://postal-codes.cybo.com/germany/12621_berlin-berlin/
# 12623 https://postal-codes.cybo.com/germany/12623_berlin-berlin/
# 12627 https://postal-codes.cybo.com/germany/12627_berlin-berlin/
# 12629 https://postal-codes.cybo.com/germany/12629_berlin-berlin/
# 12679 https://postal-codes.cybo.com/germany/12679_berlin-berlin/
# 12681 https://postal-codes.cybo.com/germany/12681_berlin-berlin/
# 12683 https://postal-codes.cybo.com/germany/12683_berlin-berlin/
# 12685 https://postal-codes.cybo.com/germany/12685_berlin-berlin/
# 12687 https://postal-codes.cybo.com/germany/12687_berlin-berlin/
# 12689 https://postal-codes.cybo.com/germany/12689_berlin-berlin/
# 13047 https://postal-codes.cybo.com/germany/13047_reinickendorf-(locality)/
# 13051 https://postal-codes.cybo.com/germany/13051_berlin-berlin/
# 13053 https://postal-codes.cybo.com/germany/13053_berlin-berlin/
# 13055 https://postal-codes.cybo.com/germany/13055_berlin-berlin/
# 13057 https://postal-codes.cybo.com/germany/13057_berlin-berlin/
# 13059 https://postal-codes.cybo.com/germany/13059_berlin-berlin/
# 13086 https://postal-codes.cybo.com/germany/13086_berlin-berlin/
# 13088 https://postal-codes.cybo.com/germany/13088_berlin-berlin/
# 13089 https://postal-codes.cybo.com/germany/13089_berlin-berlin/
# 13125 https://postal-codes.cybo.com/germany/13125_berlin-berlin/
# 13127 https://postal-codes.cybo.com/germany/13127_berlin-berlin/
# 13129 https://postal-codes.cybo.com/germany/13129_berlin-berlin/
# 13156 https://postal-codes.cybo.com/germany/13156_berlin-berlin/
# 13158 https://postal-codes.cybo.com/germany/13158_berlin-berlin/
# 13159 https://postal-codes.cybo.com/germany/13159_berlin-berlin/
# 13187 https://postal-codes.cybo.com/germany/13187_berlin-berlin/
# 13189 https://postal-codes.cybo.com/germany/13189_berlin-berlin/
# 13347 https://postal-codes.cybo.com/germany/13347_berlin-berlin/
# 13349 https://postal-codes.cybo.com/germany/13349_berlin-berlin/
# 13351 https://postal-codes.cybo.com/germany/13351_berlin-berlin/
# 13353 https://postal-codes.cybo.com/germany/13353_berlin-berlin/
# 13355 https://postal-codes.cybo.com/germany/13355_berlin-berlin/
# 13357 https://postal-codes.cybo.com/germany/13357_berlin-berlin/
# 13359 https://postal-codes.cybo.com/germany/13359_berlin-berlin/
# 13403 https://postal-codes.cybo.com/germany/13403_berlin-berlin/
# 13405 https://postal-codes.cybo.com/germany/13405_berlin-berlin/
# 13407 https://postal-codes.cybo.com/germany/13407_berlin-berlin/
# 13409 https://postal-codes.cybo.com/germany/13409_berlin-berlin/
# 13435 https://postal-codes.cybo.com/germany/13435_berlin-berlin/
# 13437 https://postal-codes.cybo.com/germany/13437_berlin-berlin/
# 13439 https://postal-codes.cybo.com/germany/13439_berlin-berlin/
# 13465 https://postal-codes.cybo.com/germany/13465_berlin-berlin/
# 13467 https://postal-codes.cybo.com/germany/13467_berlin-berlin/
# 13469 https://postal-codes.cybo.com/germany/13469_berlin-berlin/
# 13503 https://postal-codes.cybo.com/germany/13503_berlin-berlin/
# 13505 https://postal-codes.cybo.com/germany/13505_berlin-berlin/
# 13507 https://postal-codes.cybo.com/germany/13507_berlin-berlin/
# 13509 https://postal-codes.cybo.com/germany/13509_berlin-berlin/
# 13581 https://postal-codes.cybo.com/germany/13581_berlin-berlin/
# 13583 https://postal-codes.cybo.com/germany/13583_berlin-berlin/
# 13585 https://postal-codes.cybo.com/germany/13585_berlin-berlin/
# 13587 https://postal-codes.cybo.com/germany/13587_berlin-berlin/
# 13589 https://postal-codes.cybo.com/germany/13589_berlin-berlin/
# 13591 https://postal-codes.cybo.com/germany/13591_berlin-berlin/
# 13593 https://postal-codes.cybo.com/germany/13593_berlin-berlin/
# 13595 https://postal-codes.cybo.com/germany/13595_berlin-berlin/
# 13597 https://postal-codes.cybo.com/germany/13597_berlin-berlin/
# 13599 https://postal-codes.cybo.com/germany/13599_berlin-berlin/
# 13627 https://postal-codes.cybo.com/germany/13627_berlin-berlin/
# 13629 https://postal-codes.cybo.com/germany/13629_berlin-berlin/
# 14050 https://postal-codes.cybo.com/germany/14050_berlin-berlin/
# 14052 https://postal-codes.cybo.com/germany/14052_berlin-berlin/
# 14053 https://postal-codes.cybo.com/germany/14053_berlin-berlin/
# 14055 https://postal-codes.cybo.com/germany/14055_berlin-berlin/
# 14057 https://postal-codes.cybo.com/germany/14057_berlin-berlin/
# 14059 https://postal-codes.cybo.com/germany/14059_berlin-berlin/
# 14089 https://postal-codes.cybo.com/germany/14089_berlin-berlin/
# 14109 https://postal-codes.cybo.com/germany/14109_berlin-berlin/
# 14129 https://postal-codes.cybo.com/germany/14129_berlin-berlin/
# 14131 https://postal-codes.cybo.com/germany/14131_berlin-berlin/
# 14163 https://postal-codes.cybo.com/germany/14163_berlin-berlin/
# 14165 https://postal-codes.cybo.com/germany/14165_berlin-berlin/
# 14167 https://postal-codes.cybo.com/germany/14167_berlin-berlin/
# 14169 https://postal-codes.cybo.com/germany/14169_berlin-berlin/
# 14193 https://postal-codes.cybo.com/germany/14193_berlin-berlin/
# 14195 https://postal-codes.cybo.com/germany/14195_berlin-berlin/
# 14197 https://postal-codes.cybo.com/germany/14197_berlin-berlin/
# 14199 https://postal-codes.cybo.com/germany/14199_berlin-berlin/
# 14532 https://postal-codes.cybo.com/germany/14532_rudow/
# 15366 https://postal-codes.cybo.com/germany/15366_neuenhagen-bei-berlin/
# 15562 https://postal-codes.cybo.com/germany/15562_berlin-berlin/

# %%
url_protocol = 'https:'
amsterdam_html_table = amsterdam_soup.find_all('table')[1]
with open('amsterdam_details.csv', mode='w', newline='', encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file, delimiter=';')
    csv_writer.writerow(['Postal Code', 'Median Age', 'Neighborhoods', 'Latitude', 'Longitude']) # Header

    for row in amsterdam_html_table.find_all('tr'):
        if row.find('th'):
            continue
        postal_code = (row.find('td').text)
        details_url = url_protocol + row.find('td').find('a')['href']

        #we need to scrape details page for each code to get necessary information
        driver.get(details_url) 
        details_soup = BeautifulSoup(driver.execute_script("return document.body.innerHTML;"), 'html.parser')
        details_html_table = details_soup.find('table')
        for row in details_html_table.find_all('tr'):
            row = [str(column.text).replace(' km²', '').replace('Area', 'Area km²').strip() for column in row.find_all(['td', 'th'])]
            if row[0] in ['Neighborhoods']:
                neighborhoods = row[1]
            elif row[0] in ['Coordinates']:
                coords = str(row[1]).replace('°', '').split(u'\xa0/\xa0')
                latitude = coords[0]
                longitude = coords[1]
            elif row[0] in ['Median Age']:
                median_age = str(row[1]).replace(' years', '')
        csv_writer.writerow([postal_code, median_age, neighborhoods, latitude, longitude])
        csv_file.flush()
        # sleep to avoid being blocked by website protection
        sleep(random.randint(9, 13))

# %%
driver.close()
